# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\appdata\roaming\python\python312\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Placement_Prediction_data.csv')

# %%
df
# Out:
#       Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0          1   7.5               1                        1
# 1              1          2   8.9               0                        3
# 2              2          3   7.3               1                        2
# 3              3          4   7.5               1                        1
# 4              4          5   8.3               1                        2
# ...          ...        ...   ...             ...                      ...
# 9995        9995       9996   7.5               1                        1
# 9996        9996       9997   7.4               0                        1
# 9997        9997       9998   8.4               1                        3
# 9998        9998       9999   8.9               0                        3
# 9999        9999      10000   8.4               0                        1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# 1                 2       9                         4.0        Yes       Yes
# 2                 2       8                         4.8        Yes        No
# 3                 2       8                         4.4        Yes       Yes
# 4                 2       8                         4.5        Yes       Yes
# ...             ...     ...                         ...        ...       ...
# 9995              2       7                         3.9        Yes        No
# 9996              0       9                         4.8         No        No
# 9997              0       7                         4.8        Yes       Yes
# 9998              2       8                         4.8        Yes       Yes
# 9999              1       6                         3.8         No        No
#
#       12th Percentage  10th Percentage  backlogs PlacementStatus
# 0                  61               79         2       NotPlaced
# 1                  78               82         0          Placed
# 2                  79               80         2       NotPlaced
# 3                  81               80         0          Placed
# 4                  74               88         0          Placed
# ...               ...              ...       ...             ...
# 9995               85               66         4       NotPlaced
# 9996               84               67         1          Placed
# 9997               79               81         0          Placed
# 9998               71               85         0          Placed
# 9999               62               66         1       NotPlaced
#
# [10000 rows x 14 columns]

# %%
df.rename(columns={'Communication Skill Rating':'communi_rating','Workshops/Certificatios':'workshops'},inplace=True)

# %%
df=df.loc[:,~df.columns.str.contains('Unnamed')]

# %%
df
# Out:
#       StudentId  CGPA  Major Projects  workshops  Mini Projects  Skills  \
# 0             1   7.5               1          1              1       6
# 1             2   8.9               0          3              2       9
# 2             3   7.3               1          2              2       8
# 3             4   7.5               1          1              2       8
# 4             5   8.3               1          2              2       8
# ...         ...   ...             ...        ...            ...     ...
# 9995       9996   7.5               1          1              2       7
# 9996       9997   7.4               0          1              0       9
# 9997       9998   8.4               1          3              0       7
# 9998       9999   8.9               0          3              2       8
# 9999      10000   8.4               0          1              1       6
#
#       communi_rating Internship Hackathon  12th Percentage  10th Percentage  \
# 0                4.4         No        No               61               79
# 1                4.0        Yes       Yes               78               82
# 2                4.8        Yes        No               79               80
# 3                4.4        Yes       Yes               81               80
# 4                4.5        Yes       Yes               74               88
# ...              ...        ...       ...              ...              ...
# 9995             3.9        Yes        No               85               66
# 9996             4.8         No        No               84               67
# 9997             4.8        Yes       Yes               79               81
# 9998             4.8        Yes       Yes               71               85
# 9999             3.8         No        No               62               66
#
#       backlogs PlacementStatus
# 0            2       NotPlaced
# 1            0          Placed
# 2            2       NotPlaced
# 3            0          Placed
# 4            0          Placed
# ...        ...             ...
# 9995         4       NotPlaced
# 9996         1          Placed
# 9997         0          Placed
# 9998         0          Placed
# 9999         1       NotPlaced
#
# [10000 rows x 13 columns]

# %%
df.fillna(0,inplace=True)
# Out:
#       StudentId  CGPA  Major Projects  workshops  Mini Projects  Skills  \
# 0             1   7.5               1          1              1       6
# 1             2   8.9               0          3              2       9
# 2             3   7.3               1          2              2       8
# 3             4   7.5               1          1              2       8
# 4             5   8.3               1          2              2       8
# ...         ...   ...             ...        ...            ...     ...
# 9995       9996   7.5               1          1              2       7
# 9996       9997   7.4               0          1              0       9
# 9997       9998   8.4               1          3              0       7
# 9998       9999   8.9               0          3              2       8
# 9999      10000   8.4               0          1              1       6
#
#       communi_rating Internship Hackathon  12th Percentage  10th Percentage  \
# 0                4.4         No        No               61               79
# 1                4.0        Yes       Yes               78               82
# 2                4.8        Yes        No               79               80
# 3                4.4        Yes       Yes               81               80
# 4                4.5        Yes       Yes               74               88
# ...              ...        ...       ...              ...              ...
# 9995             3.9        Yes        No               85               66
# 9996             4.8         No        No               84               67
# 9997             4.8        Yes       Yes               79               81
# 9998             4.8        Yes       Yes               71               85
# 9999             3.8         No        No               62               66
#
#       backlogs PlacementStatus
# 0            2       NotPlaced
# 1            0          Placed
# 2            2       NotPlaced
# 3            0          Placed
# 4            0          Placed
# ...        ...             ...
# 9995         4       NotPlaced
# 9996         1          Placed
# 9997         0          Placed
# 9998         0          Placed
# 9999         1       NotPlaced
#
# [10000 rows x 13 columns]

# %%
df =pd.read_csv("Salary_prediction_data.csv")
df.head()
# Out:
#    Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0           0          1   7.5               1                        1
# 1           1          2   8.9               0                        3
# 2           2          3   7.3               1                        2
# 3           3          4   7.5               1                        1
# 4           4          5   8.3               1                        2
#
#    Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0              1       6                         4.4         No        No
# 1              2       9                         4.0        Yes       Yes
# 2              2       8                         4.8        Yes        No
# 3              2       8                         4.4        Yes       Yes
# 4              2       8                         4.5        Yes       Yes
#
#    12th Percentage  10th Percentage  backlogs PlacementStatus   salary
# 0               61               79         2       NotPlaced        0
# 1               78               82         0          Placed  1000000
# 2               79               80         2       NotPlaced        0
# 3               81               80         0          Placed   950000
# 4               74               88         0          Placed   950000

# %%
x=df.drop(['StudentId','PlacementStatus','salary'],axis=1)

# %%
y=df['PlacementStatus']

# %%
y
# Out:
# 0       NotPlaced
# 1          Placed
# 2       NotPlaced
# 3          Placed
# 4          Placed
#           ...
# 9995    NotPlaced
# 9996       Placed
# 9997       Placed
# 9998       Placed
# 9999    NotPlaced
# Name: PlacementStatus, Length: 10000, dtype: str

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\dell\appdata\roaming\python\python312\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.4.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
x['Internship']=le.fit_transform(x['Internship'])
x['Hackathon']=le.fit_transform(x['Hackathon'])

# %%
y=le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state = 100)

# %%
x_train
# Out:
#       Unnamed: 0  CGPA  Major Projects  Workshops/Certificatios  \
# 1191        1191   7.8               1                        2
# 4458        4458   8.7               2                        2
# 1131        1131   8.6               2                        3
# 9562        9562   7.8               1                        1
# 6579        6579   7.8               1                        2
# ...          ...   ...             ...                      ...
# 350          350   7.5               1                        2
# 79            79   7.6               1                        2
# 8039        8039   8.2               2                        3
# 6936        6936   7.6               1                        2
# 5640        5640   6.6               0                        2
#
#       Mini Projects  Skills  Communication Skill Rating  Internship  \
# 1191              1       7                         4.1           0
# 4458              2       9                         4.7           1
# 1131              2       9                         4.8           1
# 9562              0       6                         4.6           0
# 6579              1       7                         4.3           0
# ...             ...     ...                         ...         ...
# 350               0       7                         3.7           0
# 79                1       7                         3.9           0
# 8039              2       8                         4.8           1
# 6936              0       6                         4.1           0
# 5640              1       6                         4.1           0
#
#       Hackathon  12th Percentage  10th Percentage  backlogs
# 1191          1               55               63         4
# 4458          1               76               85         0
# 1131          1               73               80         0
# 9562          0               58               80         2
# 6579          0               55               68         4
# ...         ...              ...              ...       ...
# 350           1               55               66         2
# 79            1               58               66         2
# 8039          1               77               83         1
# 6936          1               55               64         4
# 5640          0               57               62         3
#
# [7000 rows x 12 columns]

# %%
x_test
# Out:
#       Unnamed: 0  CGPA  Major Projects  Workshops/Certificatios  \
# 8018        8018   6.7               1                        2
# 9225        9225   7.7               1                        2
# 3854        3854   8.4               1                        2
# 2029        2029   7.6               1                        1
# 3539        3539   8.6               2                        3
# ...          ...   ...             ...                      ...
# 4208        4208   6.5               0                        2
# 5335        5335   7.4               1                        1
# 2554        2554   8.2               2                        3
# 13            13   7.7               1                        1
# 4468        4468   8.0               2                        3
#
#       Mini Projects  Skills  Communication Skill Rating  Internship  \
# 8018              0       6                         3.9           0
# 9225              2       8                         3.9           1
# 3854              0       9                         4.7           1
# 2029              0       7                         4.1           0
# 3539              0       7                         4.2           1
# ...             ...     ...                         ...         ...
# 4208              1       8                         4.8           0
# 5335              0       6                         3.7           0
# 2554              2       9                         4.1           1
# 13                1       7                         4.6           0
# 4468              2       9                         4.8           1
#
#       Hackathon  12th Percentage  10th Percentage  backlogs
# 8018          0               59               69         2
# 9225          1               81               75         4
# 3854          1               55               81         1
# 2029          1               55               64         4
# 3539          1               79               86         0
# ...         ...              ...              ...       ...
# 4208          1               74               84         0
# 5335          0               63               64         3
# 2554          1               73               69         1
# 13            1               63               73         3
# 4468          1               82               81         0
#
# [3000 rows x 12 columns]

# %%
y_train
# Out:
# array([0, 1, 1, ..., 1, 0, 0], shape=(7000,))

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(3000,))

# %%
from sklearn.ensemble import RandomForestClassifier
classify=RandomForestClassifier(n_estimators= 100, criterion="entropy",max_depth=2)
classify.fit(x_train,y_train)
ypred=classify.predict(x_test)

# %%
ypred
# Out:
# array([0, 0, 1, ..., 1, 0, 1], shape=(3000,))

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(3000,))

# %%
from sklearn import metrics

# %%
accuracy_score=metrics.accuracy_score(y_test,ypred)

# %%
accuracy_score
# Out:
# 0.8806666666666667

# %%
confusion_metrix=metrics.confusion_matrix(y_test,ypred)

# %%
confusion_metrix
# Out:
# array([[1530,  244],
#        [ 114, 1112]])

# %%
classification_report=metrics.classification_report(y_test,ypred)

# %%
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.93      0.86      0.90      1774\n           1       0.82      0.91      0.86      1226\n\n    accuracy                           0.88      3000\n   macro avg       0.88      0.88      0.88      3000\nweighted avg       0.89      0.88      0.88      3000\n'

# %%
importances=RandomForestClassifier.feature_importances_

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\roaming\python\python312\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\roaming\python\python312\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\roaming\python\python312\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\roaming\python\python312\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
importance=classify.feature_importances_

# %%
plt.figure(figsize=(10,6))

# %%
plt.bar(x.columns,importance)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Feature Importance for Random Forest Classifier')
plt.show()

# %%
ypred_pob=classify.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=metrics.roc_curve(y_test,ypred_pob)
roc_auc=metrics.auc(fpr,tpr)
roc_auc
# Out:
# 0.9458994889016811

# %%
ypred_pob
# Out:
# array([0.07257958, 0.1957948 , 0.66251192, ..., 0.67387774, 0.08449114,
#        0.84330158], shape=(3000,))

# %%
roc_auc=metrics.auc(fpr,tpr)
roc_auc
# Out:
# 0.9458994889016811

# %%
plt.figure(figsize=(8,6))
plt.plot(fpr,tpr,label='ROC curve (area=%0.2f)'%roc_auc)
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve for Random Forest Classifier (placement oppertunities)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
from sklearn .neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
ypred=knn.predict(x_test)

# %%
ypred_knn=knn.predict(x_test)

# %%
ypred
# Out:
# array([0, 1, 0, ..., 0, 0, 1], shape=(3000,))

# %%
accuracy_score=metrics.accuracy_score(y_test,ypred)

# %%
accuracy_score
# Out:
# 0.7253333333333334

# %%
confusion_metrix=metrics.confusion_matrix(y_test,ypred)

# %%
confusion_metrix
# Out:
# array([[1370,  404],
#        [ 420,  806]])

# %%
classification_report=metrics.classification_report(y_test,ypred)

# %%
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.77      0.77      0.77      1774\n           1       0.67      0.66      0.66      1226\n\n    accuracy                           0.73      3000\n   macro avg       0.72      0.71      0.72      3000\nweighted avg       0.72      0.73      0.73      3000\n'

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(random_state=42)

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
ypred=clf.predict(x_test)

# %%
accuracy_score=metrics.accuracy_score(y_test,ypred)

# %%
accuracy_score
# Out:
# 0.9243333333333333

# %%
confusion_metrix=metrics.confusion_matrix(y_test,ypred)

# %%
confusion_metrix
# Out:
# array([[1655,  119],
#        [ 108, 1118]])

# %%
classification_report=metrics.classification_report(y_test,ypred)

# %%
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.94      0.93      0.94      1774\n           1       0.90      0.91      0.91      1226\n\n    accuracy                           0.92      3000\n   macro avg       0.92      0.92      0.92      3000\nweighted avg       0.92      0.92      0.92      3000\n'
